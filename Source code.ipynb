# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SX0ZD8veLNzKFEMKWoFm")
project = rf.workspace("machinelearning-nwizy").project("classfication-rknjw")
dataset = project.version(2).download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.6/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/Classfication-2/data.yaml epochs=35 imgsz=70
# Out:
# New https://pypi.org/project/ultralytics/8.1.9 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png', width=900)

# %%
Image(filename=f'/content/runs/detect/train2/results.png', width=600)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data=/content/Classfication-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25846708 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/Classfication-2/valid/labels.cache... 119 images, 0 backgrounds, 0 corrupt: 100% 119/119 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:05<00:00,  1.58it/s]
#                    all        119        119      0.977      0.982      0.988      0.827
#                   Cock        119         11       0.99      0.909      0.923      0.734
#         Lotus blooming        119         12          1      0.874      0.995       0.82
#          Moon crescent        119          7      0.945          1      0.995      0.855
#                 Needle        119         15      0.993          1      0.995      0.864
#       Pair of scissors        119          8       0.88          1      0.982      0.864
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source='/content/Classfication-2/test/images'
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25846708 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/59 /content/Classfication-2/test/images/Cock6_jpg.rf.e4469ed792b2835eb729526ee3e9c6f8.jpg: 96x96 1 Cock, 12.4ms
# image 2/59 /content/Classfication-2/test/images/IMG_20211017_155735_jpg.rf.f4bc16d9c371068564c6238ae318e7ce.jpg: 96x96 1 Cock, 10.9ms
# image 3/59 /content/Classfication-2/test/images/IMG_20211017_160130_jpg.rf.42f591b52d719af97b192b8db7e5798b.jpg: 96x96 1 Cock, 10.7ms
# image 4/59 /content/Classfication-2/test/images/IMG_20211017_161158_jpg.rf.32e478b67bb8209363a37c77232e639b.jpg: 96x96 1 Pair of scissors, 10.8ms
# image 5/59 /content/Classfication-2/test/images/IMG_20211017_161204_jpg.rf.0365148f240b29487d894ec816d30121.jpg: 96x96 1 Pair of scissors, 10.8ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:5]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source='/content/drive/MyDrive/WhatsApp Video 2024-01-21 at 12.00.29 AM.mp4'
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25846708 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/2713) /content/drive/MyDrive/WhatsApp Video 2024-01-21 at 12.00.29 AM.mp4: 96x64 1 Swan face, 121.3ms
# video 1/1 (2/2713) /content/drive/MyDrive/WhatsApp Video 2024-01-21 at 12.00.29 AM.mp4: 96x64 1 Swan face, 11.4ms
# video 1/1 (3/2713) /content/drive/MyDrive/WhatsApp Video 2024-01-21 at 12.00.29 AM.mp4: 96x64 1 Swan face, 14.0ms
# video 1/1 (4/2713) /content/drive/MyDrive/WhatsApp Video 2024-01-21 at 12.00.29 AM.mp4: 96x64 1 Swan face, 13.0ms
# video 1/1 (5/2713) /content/drive/MyDrive/WhatsApp Video 2024-01-21 at 12.00.29 AM.mp4: 96x64 1 Swan face, 11.5ms
# video 1/1 (6/2713) /content/drive/MyDrive/WhatsApp Video 2024-01-21 at 12.00.29 AM.mp4: 96x64 1 Swan face, 12.1ms
# video 1/1 (7/2713) /content/drive/MyDrive/WhatsApp Video 2024-01-21 at 12.00.29 AM.mp4: 96x64 1 Swan face, 11.2ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source='/content/drive/MyDrive/demo2.mp4'
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 218 layers, 25846708 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/1748) /content/drive/MyDrive/demo2.mp4: 96x64 1 Moon crescent, 1 Pair of scissors, 71.2ms
# video 1/1 (2/1748) /content/drive/MyDrive/demo2.mp4: 96x64 1 Moon crescent, 43.3ms
# video 1/1 (3/1748) /content/drive/MyDrive/demo2.mp4: 96x64 1 Moon crescent, 42.6ms
# video 1/1 (4/1748) /content/drive/MyDrive/demo2.mp4: 96x64 1 Moon crescent, 45.3ms
# video 1/1 (5/1748) /content/drive/MyDrive/demo2.mp4: 96x64 1 Moon crescent, 44.2ms
# video 1/1 (6/1748) /content/drive/MyDrive/demo2.mp4: 96x64 1 Moon crescent, 1 Pair of scissors, 45.2ms
# video 1/1 (7/1748) /content/drive/MyDrive/demo2.mp4: 96x64 1 Moon crescent, 42.3ms
# video 1/1 (8/1748) /content/drive/MyDrive/demo2.mp4: 96x64 1 Moon crescent, 1 Pair of scissors, 48.6ms
# video 1/1 (9/1748) /content/drive/MyDrive/demo2.mp4: 96x64 1 Moon crescent, 40.2ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source='/content/drive/MyDrive/WhatsApp Video 2024-01-31 at 11.08.14 PM.mp4'
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 218 layers, 25846708 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/3331) /content/drive/MyDrive/WhatsApp Video 2024-01-31 at 11.08.14 PM.mp4: 96x64 1 Swan face, 123.4ms
# video 1/1 (2/3331) /content/drive/MyDrive/WhatsApp Video 2024-01-31 at 11.08.14 PM.mp4: 96x64 1 Swan face, 65.9ms
# video 1/1 (3/3331) /content/drive/MyDrive/WhatsApp Video 2024-01-31 at 11.08.14 PM.mp4: 96x64 1 Swan face, 92.3ms
# video 1/1 (4/3331) /content/drive/MyDrive/WhatsApp Video 2024-01-31 at 11.08.14 PM.mp4: 96x64 1 Swan face, 64.4ms
# video 1/1 (5/3331) /content/drive/MyDrive/WhatsApp Video 2024-01-31 at 11.08.14 PM.mp4: 96x64 1 Swan face, 71.1ms
# video 1/1 (6/3331) /content/drive/MyDrive/WhatsApp Video 2024-01-31 at 11.08.14 PM.mp4: 96x64 1 Swan face, 75.0ms
# video 1/1 (7/3331) /content/drive/MyDrive/WhatsApp Video 2024-01-31 at 11.08.14 PM.mp4: 96x64 1 Swan face, 65.0ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source='/content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.33.04 AM.mp4'
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25846708 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/2770) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.33.04 AM.mp4: 96x64 1 Lotus blooming, 1 Swan face, 102.8ms
# video 1/1 (2/2770) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.33.04 AM.mp4: 96x64 1 Lotus blooming, 1 Swan face, 11.0ms
# video 1/1 (3/2770) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.33.04 AM.mp4: 96x64 1 Lotus blooming, 1 Swan face, 10.9ms
# video 1/1 (4/2770) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.33.04 AM.mp4: 96x64 1 Lotus blooming, 11.0ms
# video 1/1 (5/2770) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.33.04 AM.mp4: 96x64 1 Lotus blooming, 10.8ms
# video 1/1 (6/2770) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.33.04 AM.mp4: 96x64 1 Lotus blooming, 1 Swan face, 10.8ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source='/content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.52.26 AM.mp4'
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25846708 parameters, 0 gradients, 78.7 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/1492) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.52.26 AM.mp4: 96x64 1 Swan face, 107.8ms
# video 1/1 (2/1492) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.52.26 AM.mp4: 96x64 1 Swan face, 10.9ms
# video 1/1 (3/1492) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.52.26 AM.mp4: 96x64 1 Swan face, 10.7ms
# video 1/1 (4/1492) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.52.26 AM.mp4: 96x64 1 Swan face, 10.7ms
# video 1/1 (5/1492) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.52.26 AM.mp4: 96x64 1 Swan face, 10.8ms
# video 1/1 (6/1492) /content/drive/MyDrive/WhatsApp Video 2024-02-04 at 11.52.26 AM.mp4: 96x64 1 Swan face, 10.7ms
# ...

# %%
project.version(2).deploy(model_type='yolov8', model_path=('/content/runs/detect/train2/'))
# Out:
# An error occured when getting the model upload URL: This version already has a trained model. Please generate and train a new version in order to upload model to Roboflow.

# %%
# Export the model
model=YOLO('/content/runs/detect/train2/weights/best.pt')
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 218 layers, 25846708 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train2/weights/best.pt' with input shape (1, 3, 96, 96) BCHW and output shape(s) (1, 16, 189) (49.6 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 159.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 9.8s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 11.9s, saved as '/content/runs/detect/train2/weights/best.onnx' (98.7 MB)
#
# Export complete (14.8s)
# Results saved to /content/runs/detect/train2/weights
# ...
